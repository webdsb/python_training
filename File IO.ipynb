# %%
import os
labDir = './labDir'
os.path.exists(labDir)
# Out:
# False

# %%
os.mkdir(labDir)
os.listdir(labDir)
# Out:
# []

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
# ...

# %%
fileName = 'osDir.txt'
fullFileName = os.path.join(labDir, fileName); fullFileName
# Out:
# './labDir\\osDir.txt'

# %%
with open (fullFileName, 'w') as fout:
    for idx, e in enumerate(dir(os)):
        fout.write(f'{idx}:{e}\n')

# %%
fileLines = []
with open (fullFileName, 'r') as fin:
    for line in fin:
        fileLines.append(line)
fileLines
# Out:
# ['0:DirEntry\n',
#  '1:EX_OK\n',
#  '2:F_OK\n',
#  '3:GenericAlias\n',
#  '4:Mapping\n',
#  '5:MutableMapping\n',
#  '6:O_APPEND\n',
#  '7:O_BINARY\n',
#  '8:O_CREAT\n',
#  '9:O_EXCL\n',
#  '10:O_NOINHERIT\n',
#  '11:O_RANDOM\n',
#  '12:O_RDONLY\n',
#  '13:O_RDWR\n',
#  '14:O_SEQUENTIAL\n',
#  '15:O_SHORT_LIVED\n',
#  '16:O_TEMPORARY\n',
#  '17:O_TEXT\n',
#  '18:O_TRUNC\n',
#  '19:O_WRONLY\n',
#  '20:P_DETACH\n',
#  '21:P_NOWAIT\n',
#  '22:P_NOWAITO\n',
#  '23:P_OVERLAY\n',
#  '24:P_WAIT\n',
#  '25:PathLike\n',
#  '26:R_OK\n',
#  '27:SEEK_CUR\n',
#  '28:SEEK_END\n',
#  '29:SEEK_SET\n',
#  '30:TMP_MAX\n',
#  '31:W_OK\n',
#  '32:X_OK\n',
#  '33:_AddedDllDirectory\n',
#  '34:_Environ\n',
#  '35:__all__\n',
#  '36:__builtins__\n',
#  '37:__doc__\n',
#  '38:__file__\n',
#  '39:__loader__\n',
#  '40:__name__\n',
#  '41:__package__\n',
#  '42:__spec__\n',
#  '43:_check_methods\n',
#  '44:_execvpe\n',
#  '45:_exists\n',
#  '46:_exit\n',
#  '47:_fspath\n',
#  '48:_get_exports_list\n',
# ...

# %%
with open (fullFileName, 'r') as fin:
    f = [line.strip() for line in fin]

# %%
f
# Out:
# ['0:DirEntry',
#  '1:EX_OK',
#  '2:F_OK',
#  '3:GenericAlias',
#  '4:Mapping',
#  '5:MutableMapping',
#  '6:O_APPEND',
#  '7:O_BINARY',
#  '8:O_CREAT',
#  '9:O_EXCL',
#  '10:O_NOINHERIT',
#  '11:O_RANDOM',
#  '12:O_RDONLY',
#  '13:O_RDWR',
#  '14:O_SEQUENTIAL',
#  '15:O_SHORT_LIVED',
#  '16:O_TEMPORARY',
#  '17:O_TEXT',
#  '18:O_TRUNC',
#  '19:O_WRONLY',
#  '20:P_DETACH',
#  '21:P_NOWAIT',
#  '22:P_NOWAITO',
#  '23:P_OVERLAY',
#  '24:P_WAIT',
#  '25:PathLike',
#  '26:R_OK',
#  '27:SEEK_CUR',
#  '28:SEEK_END',
#  '29:SEEK_SET',
#  '30:TMP_MAX',
#  '31:W_OK',
#  '32:X_OK',
#  '33:_AddedDllDirectory',
#  '34:_Environ',
#  '35:__all__',
#  '36:__builtins__',
#  '37:__doc__',
#  '38:__file__',
#  '39:__loader__',
#  '40:__name__',
#  '41:__package__',
#  '42:__spec__',
#  '43:_check_methods',
#  '44:_execvpe',
#  '45:_exists',
#  '46:_exit',
#  '47:_fspath',
#  '48:_get_exports_list',
#  '49:_walk_symlinks_as_files',
#  '50:_wrap_close',
#  '51:abc',
#  '52:abort',
#  '53:access',
# ...

# %%
osDirFromFile = [e.split(':')[1] for e in fileLines]

# %%
osDirFromFile
# Out:
# ['DirEntry\n',
#  'EX_OK\n',
#  'F_OK\n',
#  'GenericAlias\n',
#  'Mapping\n',
#  'MutableMapping\n',
#  'O_APPEND\n',
#  'O_BINARY\n',
#  'O_CREAT\n',
#  'O_EXCL\n',
#  'O_NOINHERIT\n',
#  'O_RANDOM\n',
#  'O_RDONLY\n',
#  'O_RDWR\n',
#  'O_SEQUENTIAL\n',
#  'O_SHORT_LIVED\n',
#  'O_TEMPORARY\n',
#  'O_TEXT\n',
#  'O_TRUNC\n',
#  'O_WRONLY\n',
#  'P_DETACH\n',
#  'P_NOWAIT\n',
#  'P_NOWAITO\n',
#  'P_OVERLAY\n',
#  'P_WAIT\n',
#  'PathLike\n',
#  'R_OK\n',
#  'SEEK_CUR\n',
#  'SEEK_END\n',
#  'SEEK_SET\n',
#  'TMP_MAX\n',
#  'W_OK\n',
#  'X_OK\n',
#  '_AddedDllDirectory\n',
#  '_Environ\n',
#  '__all__\n',
#  '__builtins__\n',
#  '__doc__\n',
#  '__file__\n',
#  '__loader__\n',
#  '__name__\n',
#  '__package__\n',
#  '__spec__\n',
#  '_check_methods\n',
#  '_execvpe\n',
#  '_exists\n',
#  '_exit\n',
#  '_fspath\n',
#  '_get_exports_list\n',
#  '_walk_symlinks_as_files\n',
#  '_wrap_close\n',
#  'abc\n',
#  'abort\n',
#  'access\n',
#  'add_dll_directory\n',
#  'altsep\n',
# ...
